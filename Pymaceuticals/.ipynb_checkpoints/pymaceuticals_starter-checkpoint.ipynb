# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouseDrugDataPath = "data/mouse_drug_data.csv"
clinTrialDataPath = "data/clinicaltrial_data.csv"

#Create list of plot markers
markers = ["o", "^", "s", "d", "p", "X", "P"]
colors = ["r", "b", "g", "k"]

# Read the Mouse and Drug Data and the Clinical Trial Data
mouseDrugData = pd.read_csv(mouseDrugDataPath)
mouseDrugDF = pd.DataFrame(mouseDrugData)
clinTrialData = pd.read_csv(clinTrialDataPath)
clinTrialDF = pd.DataFrame(clinTrialData)

# Combine the data into a single dataset
combinedDF = pd.merge(mouseDrugDF, clinTrialDF, on="Mouse ID", suffixes=["_m", "_c"])

# Display the data table for preview
combinedDF
# Out:
#      Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        f234  Stelasyn          0           45.000000                 0
# 1        f234  Stelasyn          5           47.313491                 0
# 2        f234  Stelasyn         10           47.904324                 0
# 3        f234  Stelasyn         15           48.735197                 1
# 4        f234  Stelasyn         20           51.112713                 2
# ...       ...       ...        ...                 ...               ...
# 1901     j235   Placebo          0           45.000000                 0
# 1902     j235   Placebo          5           46.588820                 0
# 1903     j235   Placebo         10           48.018788                 1
# 1904     j235   Placebo         15           51.161138                 1
# 1905     j235   Placebo         20           52.942902                 1
#
# [1906 rows x 5 columns]

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
meanTumData = combinedDF.groupby(["Drug", "Timepoint"]).aggregate({"Tumor Volume (mm3)" : "mean"})

# Convert back to DataFrame
meanTumData = meanTumData.reset_index()

# Preview DataFrame
meanTumData
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# ..        ...        ...                 ...
# 95  Zoniferol         25           55.432935
# 96  Zoniferol         30           57.713531
# 97  Zoniferol         35           60.089372
# 98  Zoniferol         40           62.916692
# 99  Zoniferol         45           65.960888
#
# [100 rows x 3 columns]

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
stdErrTumData = combinedDF.groupby(["Drug", "Timepoint"]).aggregate({"Tumor Volume (mm3)" : "sem"})

# Convert to DataFrame
stdErrTumData = stdErrTumData.reset_index()
# Preview DataFrame
stdErrTumData
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# ..        ...        ...                 ...
# 95  Zoniferol         25            0.602513
# 96  Zoniferol         30            0.800043
# 97  Zoniferol         35            0.881426
# 98  Zoniferol         40            0.998515
# 99  Zoniferol         45            1.003576
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
meanPivot = meanTumData.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")
stdErrPivot = stdErrTumData.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")

#Get x_axis
tumData_x_axis = [row for row in meanPivot.index]

# Preview that Reformatting worked
#meanPivot.head()
stdErrPivot.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots(figsize=(12,8))

#Set x limit
ax.set_xlim(-2, max(tumData_x_axis) + 2)

#Reset iterable to use for different line marker
i = 0

#Add Labels
ax.set_xlabel("Time (Days)")
ax.set_ylabel("Tumor Volume (mm3)")
ax.set_title("Tumor Response to Treatment")
for col in ["Capomulin", "Infubinol", "Ketapril", "Placebo"]:
    ax.errorbar(tumData_x_axis, meanPivot[col], stdErrPivot[col], fmt=markers[i], linestyle=":", label=col, color=colors[i])
    i += 1
    
#Show legend and horizontal gridlines
ax.legend()
ax.yaxis.grid()

# Save the Figure
plt.savefig("images/HWTumorReponse.png")

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
meanMSData = combinedDF.groupby(["Drug", "Timepoint"]).aggregate({"Metastatic Sites" : "mean"})

# Convert to DataFrame
meanMSData = meanMSData.reset_index()

# Preview DataFrame
meanMSData
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# ..        ...        ...               ...
# 95  Zoniferol         25          1.687500
# 96  Zoniferol         30          1.933333
# 97  Zoniferol         35          2.285714
# 98  Zoniferol         40          2.785714
# 99  Zoniferol         45          3.071429
#
# [100 rows x 3 columns]

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
stdErrMSData = combinedDF.groupby(["Drug", "Timepoint"]).aggregate({"Metastatic Sites" : "sem"})

# Convert to DataFrame
stdErrMSData = stdErrMSData.reset_index()

# Preview DataFrame
stdErrMSData
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# ..        ...        ...               ...
# 95  Zoniferol         25          0.236621
# 96  Zoniferol         30          0.248168
# 97  Zoniferol         35          0.285714
# 98  Zoniferol         40          0.299791
# 99  Zoniferol         45          0.286400
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
meanMSPivot = meanMSData.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")
stdErrMSPivot = stdErrMSData.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")

#Get x_axis
MSData_x_axis = [row for row in meanMSPivot.index]

# Preview that Reformatting worked
#meanMSPivot.head()
stdErrMSPivot.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.095219  0.066332  0.087178   0.077709
# 10         0.105690  0.090289  0.123672   0.109109
# 15         0.136377  0.115261  0.153439   0.111677
# 20         0.171499  0.119430  0.200905   0.166378

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots(figsize=(12,8))

#Set x limit
ax.set_xlim(-2, max(MSData_x_axis) + 2)

#Reset iterable to use for different line marker
i = 0

#Add Labels
ax.set_xlabel("Treatment Duration (Days)")
ax.set_ylabel("Metastatic Sites")
ax.set_title("Metastatic Spread During Treatment")
for col in ["Capomulin", "Infubinol", "Ketapril", "Placebo"]:
    ax.errorbar(MSData_x_axis, meanMSPivot[col], stdErrMSPivot[col], fmt=markers[i], linestyle=":", label=col, color=colors[i])
    i += 1
    
#Show legend and horizontal gridlines
ax.legend()
ax.yaxis.grid()

# Save the Figure
plt.savefig("images/HWMetaSpread.png")

# %%
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
survivalCount = combinedDF.groupby(["Drug", "Timepoint"]).aggregate({"Mouse ID" : "count"})

# Convert to DataFrame
survivalCount = survivalCount.reset_index()
survivalCount = survivalCount.rename(columns={"Mouse ID" : "Mouse Count"})

# Preview DataFrame
survivalCount
# Out:
#          Drug  Timepoint  Mouse Count
# 0   Capomulin          0           25
# 1   Capomulin          5           25
# 2   Capomulin         10           25
# 3   Capomulin         15           24
# 4   Capomulin         20           23
# ..        ...        ...          ...
# 95  Zoniferol         25           16
# 96  Zoniferol         30           15
# 97  Zoniferol         35           14
# 98  Zoniferol         40           14
# 99  Zoniferol         45           14
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
survPivot = survivalCount.pivot(index="Timepoint", columns="Drug", values="Mouse Count")

#Generate x axis
survData_x_axis = [row for row in survPivot.index]

# Preview the Data Frame
survPivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
# Generate the Plot (Accounting for percentages)
fig, ax = plt.subplots(figsize=(12,8))

#Set x limit
ax.set_xlim(-2, max(survData_x_axis) + 2)

#Reset iterable to use for different line marker
i = 0

#Add Labels
ax.set_xlabel("Time (Days)")
ax.set_ylabel("Survival Rate (%)")
ax.set_title("Survival During Treatment")

for col in ["Capomulin", "Infubinol", "Ketapril", "Placebo"]:
    ax.plot(MSData_x_axis, (100 * survPivot[col])/survPivot[col][0], marker=markers[i], linestyle=":", label=col, color=colors[i])
    i += 1
    
#Show legend and horizontal gridlines
ax.legend(loc='lower left')
ax.grid()

# Save the Figure
plt.savefig("images/HWSurvivalRates.png")

# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
changes = {}

#Loop through each column; find initial size, final size, then calculate percent change and store the results
for col in meanPivot.columns:
    initSize = meanPivot[col][0]
    finalSize = meanPivot[col][45]
    percChange = 100* (finalSize - initSize)/initSize
    changes[col] = percChange
    
# Display the data to confirm
changes
# Out:
# {'Capomulin': -19.475302667894173,
#  'Ceftamin': 42.51649185589744,
#  'Infubinol': 46.12347172785188,
#  'Ketapril': 57.028794686606076,
#  'Naftisol': 53.92334713476923,
#  'Placebo': 51.29796048315153,
#  'Propriva': 47.24117486320637,
#  'Ramicane': -22.320900462766673,
#  'Stelasyn': 52.08513428789903,
#  'Zoniferol': 46.57975086509525}

# %%
# Store all Relevant Percent Changes into a Tuple
relPercChanges = (changes["Capomulin"], changes["Infubinol"], changes["Ketapril"], changes["Placebo"])
drugs = ["Capomulin", "Infubinol", "Ketapril", "Placebo"]

# Splice the data between passing and failing drugs
passDrugs = [value for value in relPercChanges if value < 0]
failDrugs = [value for value in relPercChanges if value >= 0]

#Set up y_pos's
y_pos = np.arange(len(relPercChanges))
y_pos_pass = 0
y_pos_fail = np.arange(1, len(failDrugs) + 1)

# Orient widths. Add labels, tick marks, etc. 
fig, ax = plt.subplots(figsize=(12,8))

plt.title("Tumor Change over 45 Day Treatment")
plt.ylabel("% Tumor Volume Change")
plt.xticks(y_pos, drugs) #set xticks
plt.grid() #add grid

rectsPass = plt.bar(y_pos_pass, passDrugs, align="edge", width=-1, color="green")
rectsFail = plt.bar(y_pos_fail, failDrugs, align="edge", width=-1, color="red")

# Use functions to label the percentages of changes
def autolabel(rects, ax):
    #Adapted from http://composition.al/blog/2015/11/29/a-better-way-to-add-labels-to-bar-charts-with-matplotlib/
    # Get y-axis height to calculate label position from.
    (y_bottom, y_top) = ax.get_ylim()
    y_height = y_top - y_bottom
    
    #Loop through rectangles
    for rect in rects:
        height = rect.get_height()
        
        #If height is positive or zero, place label above y=0, otherwise place it below
        if height >= 0:
            label_position = y_height * 0.025
        elif height < 0:
            label_position = -(y_height * 0.05)
            
        #Set text position and format text
        ax.text(rect.get_x() + rect.get_width()/2., label_position,
                f'{int(height)} %',
                ha='center', va='bottom', color="white")

# Call functions to implement the function calls
autolabel(rectsPass, ax)
autolabel(rectsFail, ax)

# Save the Figure
plt.savefig("images/HWSurvivalRates.png")

# Show the Figure
fig.show()

# %% [markdown]
# # Report
# ## Observation 1:
# ### Capomulin seems to be the most effective of the three drugs in fighting this type of cancer. The tumor sizes shrink over time. It also shows the slowest spread of metastatic sites, although it does not prevent the cancer from spreading. Capomulin also has the highest survival rate of the drugs
#
# ## Observation 2:
# ### Infubinol seems to be slightly deadly. The survival rates for mice on Infubinol were less than mice on no drug at all (placebo). However, Infubinol was the second best of the three drugs in slowing tumor growth and preventing the spread of metastatic sites.
#
# ## Observation 3:
# ### Each of the drugs helps slow the progression of the cancer except for Ketapril, which seems to slightly increase growth rate but decreases spread of metastatic sites until late in the treatment, as compared to a placebo.
